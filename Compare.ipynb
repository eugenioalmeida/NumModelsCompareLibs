# %% [markdown]
# # Notebook para leitura de arquivos CTL

# %% [markdown]
# ## RegEx

# %% [markdown]
# RegEx é um método para identificar strings que estejam incorporadas em textos de caracteres (THOMPSON, 1968).
# No escopo do nosso projeto, ela foi utilizada para auxiliar na busca de informações relevantes dentro de um arquivo CTL.

# %% [markdown]
# ## CTL

# %% [markdown]
# O arquivo CTL pode ser tratado basicamente como um arquivo de texto, no qual são descritos os metadados dos arquivos GRIB.

# %%
import re

# Basepath for the file
CTL_PATH = r'GPOSNMC20170906122017090612P.inz.TQ0666L064.ctl'
# CTL_PATH = r'GPOSNMC20170906122017090618P.fct.TQ0666L064.ctl'

# Open the file
ctl = open(CTL_PATH)
content = ctl.read()
print(content)
# Out:
# dset ^GPOSNMC20170906122017090612P.inz.TQ0666L064.grb
# *
# index ^GPOSNMC20170906122017090612P.inz.TQ0666L064.idx
# *
# undef -2.56E+33
# *
# title PRESSURE HISTORY    PTEC AGCM REVIS 1.0 2000  T066664   COLD
# *
# dtype grib   255
# *
# options yrev
# *
# xdef  2000 linear    0.000   0.1800000000
# ydef  1000 linear  -89.910   0.1800000000
# tdef     1 linear 12Z06SEP2017 6hr
# *
# zdef    33 levels  1020 1000  975  950  925  900  875  850  825  800
#                   775  750  725  700  675  650  600  550  500  450
#                   400  350  300  250  200  150  100   70   50   30
#                    20   10    3
# vars    30
# topo  0 132,1,0 ** surface TOPOGRAPHY [m]
# lsmk  0  81,1,0 ** surface LAND SEA MASK [0,1]
# PSLC    0  135,    1,    0  ** sfc    SURFACE PRESSURE                        (HPA             )
# UVES    0  192,    1,    0  ** sfc    SURFACE ZONAL WIND (U)                  (M/S             )
# UVEL   33   33,  100,    0  **        ZONAL WIND (U)                          (M/S             )
# VVES    0  194,    1,    0  ** sfc    SURFACE MERIDIONAL WIND (V)             (M/S             )
# VVEL   33   34,  100,    0  **        MERIDIONAL WIND (V)                     (M/S             )
# OMEG   33   39,  100,    0  **        OMEGA                                   (PA/S            )
# VORT   33   43,  100,    0  **        VORTICITY                               (1/S             )
# FCOR   33   35,  100,    0  **        STREAM FUNCTION                         (M2/S            )
# POTV   33   36,  100,    0  **        VELOCITY POTENTIAL                      (M2/S            )
# ZGEO   33    7,  100,    0  **        GEOPOTENTIAL HEIGHT                     (GPM             )
# PSNM    0    2,  102,    0  ** msl    SEA LEVEL PRESSURE                      (HPA             )
# TEMS    0  188,    1,    0  ** sfc    SURFACE ABSOLUTE TEMPERATURE            (K               )
# TEMP   33   11,  100,    0  **        ABSOLUTE TEMPERATURE                    (K               )
# UMRS    0  226,    1,    0  ** sfc    SURFACE RELATIVE HUMIDITY               (NO DIM          )
# UMRL   33   52,  100,    0  **        RELATIVE HUMIDITY                       (NO DIM          )
# UMES   33   51,  100,    0  **        SPECIFIC HUMIDITY                       (KG/KG           )
# AGPL    0   54,  200,    0  ** atm    INST. PRECIPITABLE WATER                (KG/M2           )
# TSFC    0  187,    1,    0  ** sfc    SURFACE TEMPERATURE                     (K               )
# DSTP    0   85,  112,    0  ** landt  DEEP SOIL TEMPERATURE                   (K               )
# USSL    0  182,    1,    0  ** sfc    SOIL WETNESS OF SURFACE                 (0-1             )
# UZRS    0  183,  112,    0  ** landt  SOIL WETNESS OF ROOT ZONE               (0-1             )
# UZDS    0  184,  112,    0  ** landt  SOIL WETNESS OF DRAINAGE ZONE           (0-1             )
# TP2M    0  128,  105,    2  ** sfc2m  TEMPERATURE AT 2-M FROM SURFACE         (K               )
# Q02M    0  199,    1,    0  ** sfc    SPECIFIC HUMIDITY AT 2-M FROM SURFACE   (KG/KG           )
# DO2A    0  155,  105,    2  ** sfc2m  PARTIAL OXYGEN DENSITY                  (g/m**3          )
# ICEP   33  185,  100,    0  **        ICE MIXING RATIO PROGNOSTIC             (KG/KG           )
# LIQP   33  186,  100,    0  **        LIQ MIXING RATIO PROGNOSTIC             (KG/KG           )
# CLDP   33  176,  100,    0  **        CLOUD TOTAL PROGNOSTIC                  (%               )
# endvars

# %% [markdown]
# ## Obtendo Informações

# %% [markdown]
# A função abaixo tem como objetivo obter os valores x, y e t do ctl.
#
# 1. x = pontos de longitude
# 2. y = pontos de latitude
# 3. t = quantos valores sobre o tempo/horário

# %%
def get_xyt(ctl_file):
    ctl_file.seek(0)
    content = ctl_file.read()
    
    # Pattern to get the xyt vars
    pattern = re.compile(r'\d+(?=\slinear)')
    matches = pattern.finditer(content)
    
    # List to store the values
    xyt = []
    
    for m in matches:
        xyt.append(int(m.group()))
    
    return (xyt)

x, y, t = get_xyt(ctl)
print(x, y, t)
# Out:
# (2000, 1000, 1)

# %% [markdown]
# Retornar a quantidade de níveis de pressão em que as variáveis meteorológicas se encontram.

# %%
def get_total_levels(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    # (?<=zdef\s{4})\d+ --> wrong
    
    # RegEx pattern
    pattern = re.compile(r"(?<=zdef\s{4})\d+")
    matches = pattern.search(ctl_content)

    return matches.group()

tot_levels = get_total_levels(ctl)
tot_levels
# Out:
# '33'

# %% [markdown]
# Obter a quantidade total de variáveis meteorológicas contidas no arquivo

# %%
# Get the total number of meteorological variables in the file
def get_total_vars(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    
    # RegEx pattern to get the vars.
    pattern = re.compile(r"(?<=vars(\s{4}))\d+")
    match = pattern.search(ctl_content)
    return match.group()

tot = get_total_vars(ctl)
tot
# Out:
# '30'

# %% [markdown]
# Obter o nome do arquivo GRIB com o qual o Ctl foi gerado.

# %%
# This function is to get the correspondent grib file that the ctl is related to.
def get_file_name(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    pattern = re.compile(r'(?<=dset\s\^)[A-Za-z0-9]+\.?(fct|icn|inz)?\.?[a-zA-Z0-9]*\.(grb|grib2)')
    match = pattern.search(ctl_content)
    return match.group()

dset_grib = get_file_name(ctl)
dset_grib
# Out:
# 'GPOSNMC20170906122017090612P.inz.TQ0666L064.grb'

# %% [markdown]
# Retorna informações sobre o início de cada valor de latitude e longitude, bem como a variação em graus entre eles.

# %%
# Function to get the starting point in lats and lons.
# It also returns the spacing between each point.
def get_space_latlons(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    
    # Pattern to get the starting and spacing
    pattern = re.compile(r'[-+]?[0-9]+\.\d{3,10}')
    matches = pattern.finditer(ctl_content)

    keys = ['lon_start', 'lon_dist', 'lat_start', 'lat_dist']
    values = []
    info = {}

    values = [m.group() for m in matches]
    
    # Make a dict with the values
    for i, j in enumerate(keys):
        info[j] = values[i]

    return info

info_about_coords = get_space_latlons(ctl)
info_about_coords
# Out:
# {'lat_dist': '0.1800000000',
#  'lat_start': '-89.910',
#  'lon_dist': '0.1800000000',
#  'lon_start': '0.000'}

# %% [markdown]
# Retorna as unidades de cada variável meteorológica. Está funcionando mas não está 100% perfeita. As expressões regulares estão retornando espaços vazios junto com os matches.

# %%
def get_vars_units(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    pattern = re.compile(r'(?<=(\(|\[))[A-Za-z*0-9,\%/-]*\s?[A-Za-z*0-9,\%/-]*(\s+|\])\W')
    matches = pattern.finditer(ctl_content)

    for m in matches:
        print(m.group()[:-2])

get_vars_units(ctl)
# Out:
# m
# 0,1
# HPA
# M/S
# M/S
# M/S
# M/S
# PA/S
# 1/S
# M2/S
# M2/S
# GPM
# HPA
# K
# K
# NO DIM
# NO DIM
# KG/KG
# KG/M2
# K
# K
# 0-1
# 0-1
# 0-1
# K
# KG/KG
# g/m**3
# KG/KG
# KG/KG
# %

# %% [markdown]
# Para obter os nomes das variáveis foram utilizadas as colunas padrões do Ctl. Foi observado que o arquivo segue uma estrutura sempre padrão na sua formatação, sendo possível obter as informações necessárias apenas por indexando as colunas pois é fato que as informações estarão sempre nas mesmas posições.

# %% [markdown]
# Existem 2 variáveis que parecem ser padrões no início de todo arquivo. Para efeitos de teste, elas foram consideradas padrão.

# %%
def get_start_end_vars(ctl_file):
    ctl_file.seek(0)
    start, end = 0, 0 
    for no, line in enumerate(ctl_file):
        if line[:4] == 'vars':
            # Add 1 because it starts at 0
            start = no + 1
        if line[:7] == 'endvars':
            end = no + 1

    return start, end

def get_name_vars(ctl_file, start_line, end_line):
    ctl_file.seek(0)
    var_list = []
    for n, l in enumerate(ctl_file):
        if n > start_line + 1 and n < end_line:
            var = l[38:78]
            var_list.append(var)
    two_vars = get_two_vars(ctl_file)
    for t in two_vars:
        var_list.append(t)
#     print(two_vars)
    return var_list

# Get the first 2 vars in the ctl file
# They are pattern variables and never change
# Consider them
def get_two_vars(ctl_file):
    ctl_file.seek(0)
    ctl_content = ctl_file.read()
    pattern = re.compile(r'surface\s[A-Z]*\s?[A-Z]*\s?[A-Z]*')
    matches = pattern.finditer(ctl_content)
    var = []
    for m in matches:
        var.append(m.group().strip())
    return var

start, end = get_start_end_vars(ctl)
grib_vars = get_name_vars(ctl, start, end)
for v in grib_vars:
    print(v)
# Out:
# SURFACE PRESSURE
# SURFACE ZONAL WIND (U)
# ZONAL WIND (U)
# SURFACE MERIDIONAL WIND (V)
# MERIDIONAL WIND (V)
# OMEGA
# VORTICITY
# STREAM FUNCTION
# VELOCITY POTENTIAL
# GEOPOTENTIAL HEIGHT
# SEA LEVEL PRESSURE
# SURFACE ABSOLUTE TEMPERATURE
# ABSOLUTE TEMPERATURE
# SURFACE RELATIVE HUMIDITY
# RELATIVE HUMIDITY
# SPECIFIC HUMIDITY
# INST. PRECIPITABLE WATER
# SURFACE TEMPERATURE
# DEEP SOIL TEMPERATURE
# SOIL WETNESS OF SURFACE
# SOIL WETNESS OF ROOT ZONE
# SOIL WETNESS OF DRAINAGE ZONE
# TEMPERATURE AT 2-M FROM SURFACE
# SPECIFIC HUMIDITY AT 2-M FROM SURFACE
# PARTIAL OXYGEN DENSITY
# ICE MIXING RATIO PROGNOSTIC
# LIQ MIXING RATIO PROGNOSTIC
# CLOUD TOTAL PROGNOSTIC
#
# surface TOPOGRAPHY
# surface LAND SEA MASK

# %% [markdown]
# ## Arquivo GRIB

# %% [markdown]
# Os teste foram realizados apenas com os arquivos no formato GRIB1.

# %%
import pygrib
GRIB_PATH = r'GPOSNMC20170906122017090612P.inz.TQ0666L064.grb'
grib = pygrib.open(GRIB_PATH)

# Saida das mensagens GRIB
for msg in grib:
    print(msg)
# Out:
# 1:Topography:m (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 2:Land sea mask:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 3:Surface pressure:hPa (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 4:Surface zonal wind (u):m s**-1 (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 5:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 6:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 7:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 8:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 9:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 10:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 11:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 12:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 13:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 14:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 15:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 16:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 17:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 18:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 19:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 20:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 21:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 22:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 23:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 24:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 25:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 26:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 27:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 28:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 29:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 30:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 31:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 32:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 33:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 34:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 35:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 36:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 37:Zonal wind (u):m s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 38:Surface meridional wind (v):m s**-1 (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 39:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 40:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 41:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 42:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 43:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 44:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 45:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 46:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 47:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 48:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 49:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 50:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 51:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 52:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 53:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 54:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 55:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 56:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 57:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 58:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 59:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 60:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 61:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 62:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 63:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 64:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 65:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 66:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 67:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 68:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 69:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 70:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 71:Meridional wind (v):m s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 72:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 73:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 74:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 75:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 76:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 77:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 78:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 79:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 80:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 81:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 82:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 83:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 84:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 85:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 86:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 87:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 88:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 89:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 90:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 91:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 92:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 93:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 94:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 95:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 96:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 97:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 98:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 99:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 100:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 101:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 102:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 103:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 104:Omega:Pa s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 105:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 106:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 107:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 108:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 109:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 110:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 111:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 112:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 113:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 114:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 115:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 116:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 117:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 118:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 119:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 120:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 121:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 122:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 123:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 124:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 125:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 126:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 127:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 128:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 129:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 130:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 131:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 132:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 133:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 134:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 135:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 136:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 137:Vorticity:s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 138:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 139:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 140:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 141:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 142:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 143:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 144:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 145:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 146:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 147:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 148:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 149:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 150:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 151:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 152:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 153:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 154:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 155:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 156:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 157:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 158:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 159:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 160:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 161:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 162:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 163:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 164:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 165:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 166:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 167:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 168:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 169:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 170:Stream function:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 171:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 172:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 173:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 174:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 175:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 176:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 177:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 178:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 179:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 180:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 181:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 182:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 183:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 184:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 185:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 186:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 187:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 188:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 189:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 190:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 191:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 192:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 193:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 194:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 195:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 196:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 197:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 198:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 199:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 200:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 201:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 202:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 203:Velocity potential:m**2 s**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 204:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 205:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 206:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 207:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 208:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 209:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 210:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 211:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 212:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 213:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 214:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 215:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 216:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 217:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 218:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 219:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 220:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 221:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 222:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 223:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 224:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 225:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 226:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 227:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 228:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 229:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 230:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 231:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 232:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 233:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 234:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 235:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 236:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 237:Pressure reduced to msl:hPa (instant):regular_ll:meanSea:level 0:fcst time 0 6 hr periods:from 201709061200
# 238:Surface absolute temperature:K (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 239:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 240:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 241:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 242:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 243:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 244:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 245:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 246:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 247:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 248:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 249:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 250:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 251:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 252:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 253:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 254:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 255:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 256:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 257:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 258:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 259:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 260:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 261:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 262:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 263:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 264:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 265:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 266:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 267:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 268:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 269:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 270:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 271:Absolute temperature:K (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 272:Surface relative humidity:~ (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 273:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 274:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 275:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 276:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 277:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 278:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 279:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 280:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 281:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 282:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 283:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 284:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 285:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 286:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 287:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 288:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 289:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 290:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 291:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 292:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 293:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 294:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 295:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 296:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 297:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 298:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 299:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 300:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 301:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 302:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 303:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 304:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 305:Relative humidity:~ (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 306:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 307:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 308:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 309:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 310:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 311:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 312:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 313:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 314:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 315:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 316:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 317:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 318:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 319:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 320:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 321:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 322:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 323:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 324:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 325:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 326:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 327:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 328:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 329:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 330:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 331:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 332:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 333:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 334:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 335:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 336:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 337:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 338:Specific humidity:kg kg**-1 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 339:Inst. precipitable water:kg m**-2 (instant):regular_ll:entireAtmosphere:level 0:fcst time 0 6 hr periods:from 201709061200
# 340:Surface temperature:K (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 341:Deep soil temperature:K (instant):regular_ll:depthBelowLandLayer:level None:fcst time 0 6 hr periods:from 201709061200
# 342:Soil wetness of surface:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 343:Soil wetness of root zone:(0 - 1) (instant):regular_ll:depthBelowLandLayer:level None:fcst time 0 6 hr periods:from 201709061200
# 344:Soil wetness of drainage zone:(0 - 1) (instant):regular_ll:depthBelowLandLayer:level None:fcst time 0 6 hr periods:from 201709061200
# 345:2 metre temperature:K (instant):regular_ll:heightAboveGround:level 2:fcst time 0 6 hr periods:from 201709061200
# 346:var199 undefined:unknown (instant):regular_ll:surface:level 0:fcst time 0 6 hr periods:from 201709061200
# 347:Flight levels u-wind:m s**-1 (instant):regular_ll:heightAboveGround:level 2:fcst time 0 6 hr periods:from 201709061200
# 348:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 349:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 350:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 351:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 352:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 353:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 354:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 355:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 356:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 357:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 358:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 359:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 360:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 361:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 362:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 363:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 364:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 365:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 366:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 367:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 368:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 369:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 370:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 371:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 372:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 373:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 374:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 375:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 376:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 377:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 378:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 379:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 380:Storage on canopy:m (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 381:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 382:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 383:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 384:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 385:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 386:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 387:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 388:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 389:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 390:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 391:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 392:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 393:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 394:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 395:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 396:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 397:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 398:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 399:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 400:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 401:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 402:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 403:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 404:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 405:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 406:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 407:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 408:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 409:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 410:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 411:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 412:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 413:Storage on ground:m (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200
# 414:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 1020:fcst time 0 6 hr periods:from 201709061200
# 415:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 1000:fcst time 0 6 hr periods:from 201709061200
# 416:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 975:fcst time 0 6 hr periods:from 201709061200
# 417:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 950:fcst time 0 6 hr periods:from 201709061200
# 418:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 925:fcst time 0 6 hr periods:from 201709061200
# 419:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 900:fcst time 0 6 hr periods:from 201709061200
# 420:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 875:fcst time 0 6 hr periods:from 201709061200
# 421:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 850:fcst time 0 6 hr periods:from 201709061200
# 422:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 825:fcst time 0 6 hr periods:from 201709061200
# 423:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 800:fcst time 0 6 hr periods:from 201709061200
# 424:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 775:fcst time 0 6 hr periods:from 201709061200
# 425:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 750:fcst time 0 6 hr periods:from 201709061200
# 426:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 725:fcst time 0 6 hr periods:from 201709061200
# 427:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 700:fcst time 0 6 hr periods:from 201709061200
# 428:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 675:fcst time 0 6 hr periods:from 201709061200
# 429:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 650:fcst time 0 6 hr periods:from 201709061200
# 430:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 600:fcst time 0 6 hr periods:from 201709061200
# 431:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 550:fcst time 0 6 hr periods:from 201709061200
# 432:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 500:fcst time 0 6 hr periods:from 201709061200
# 433:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 450:fcst time 0 6 hr periods:from 201709061200
# 434:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 400:fcst time 0 6 hr periods:from 201709061200
# 435:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 350:fcst time 0 6 hr periods:from 201709061200
# 436:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 300:fcst time 0 6 hr periods:from 201709061200
# 437:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 250:fcst time 0 6 hr periods:from 201709061200
# 438:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 200:fcst time 0 6 hr periods:from 201709061200
# 439:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 150:fcst time 0 6 hr periods:from 201709061200
# 440:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 100:fcst time 0 6 hr periods:from 201709061200
# 441:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 70:fcst time 0 6 hr periods:from 201709061200
# 442:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 50:fcst time 0 6 hr periods:from 201709061200
# 443:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 30:fcst time 0 6 hr periods:from 201709061200
# 444:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 20:fcst time 0 6 hr periods:from 201709061200
# 445:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 10:fcst time 0 6 hr periods:from 201709061200
# 446:Bare soil latent heat:Ws m**-2 (instant):regular_ll:isobaricInhPa:level 3:fcst time 0 6 hr periods:from 201709061200

# %%
msg = grib[10]
for key in sorted(msg.keys()):
    print(key)
# Out:
# GRIBEX_boustrophedonic
# GRIBEditionNumber
# Ni
# Nj
# P1
# P2
# PLPresent
# PVPresent
# UseEcmfConventions
# WMO
# additionalFlagPresent
# alternativeRowScanning
# analDate
# angularPrecision
# average
# binaryScaleFactor
# bitMapIndicator
# bitmapPresent
# bitsPerValue
# bitsPerValueAndRepack
# boustrophedonic
# centre
# centreDescription
# centuryOfReferenceTimeOfData
# cfName
# cfNameECMF
# cfVarName
# cfVarNameECMF
# changeDecimalPrecision
# complexPacking
# constantFieldHalfByte
# dataDate
# dataFlag
# dataLength
# dataRepresentationType
# dataTime
# day
# decimalPrecision
# decimalScaleFactor
# deleteLocalDefinition
# deletePV
# distinctLatitudes
# distinctLongitudes
# earthIsOblate
# editionNumber
# endStep
# eps
# generatingProcessIdentifier
# getNumberOfValues
# globalDomain
# gridDefinition
# gridDefinitionDescription
# gridDefinitionTemplateNumber
# gridDescriptionSectionPresent
# gridType
# halfByte
# hideThis
# hour
# hundred
# iDirectionIncrement
# iDirectionIncrementInDegrees
# iScansNegatively
# iScansPositively
# ifsParam
# ijDirectionIncrementGiven
# indicatorOfParameter
# indicatorOfTypeOfLevel
# integerPointValues
# isConstant
# jDirectionIncrement
# jDirectionIncrementInDegrees
# jPointsAreConsecutive
# jScansPositively
# julianDay
# kurtosis
# latLonValues
# latitudeOfFirstGridPoint
# latitudeOfFirstGridPointInDegrees
# latitudeOfLastGridPoint
# latitudeOfLastGridPointInDegrees
# latitudes
# lengthOfHeaders
# level
# localUsePresent
# longitudeOfFirstGridPoint
# longitudeOfFirstGridPointInDegrees
# longitudeOfLastGridPoint
# longitudeOfLastGridPointInDegrees
# longitudes
# marsParam
# maximum
# minimum
# minute
# missingValue
# month
# name
# nameECMF
# neitherPresent
# numberIncludedInAverage
# numberMissingFromAveragesOrAccumulations
# numberOfCodedValues
# numberOfDataPoints
# numberOfMissing
# numberOfValues
# numberOfVerticalCoordinateValues
# offsetSection0
# offsetValuesBy
# orderOfSPD
# packingError
# packingType
# paramId
# paramIdECMF
# parameterName
# parameterUnits
# parametersVersion
# pressureUnits
# productionStatusOfProcessedData
# pvlLocation
# radius
# referenceValue
# referenceValueError
# resolutionAndComponentFlags
# resolutionAndComponentFlags3
# resolutionAndComponentFlags4
# resolutionAndComponentFlags6
# resolutionAndComponentFlags7
# resolutionAndComponentFlags8
# scaleValuesBy
# scanningMode
# scanningMode4
# scanningMode5
# scanningMode6
# scanningMode7
# scanningMode8
# second
# section0Length
# section1Length
# section2Length
# section4Length
# section5Length
# setLocalDefinition
# shortName
# shortNameECMF
# skewness
# sphericalHarmonics
# standardDeviation
# startStep
# stepRange
# stepType
# stepUnits
# subCentre
# table2Version
# tableReference
# timeRangeIndicator
# totalLength
# typeOfLevel
# typeOfLevelECMF
# unitOfTimeRange
# units
# unitsECMF
# unpackedError
# uvRelativeToGrid
# validDate
# validityDate
# validityTime
# values
# wrongPadding
# year
# yearOfCentury

# %% [markdown]
# ### Referências
#
# THOMPSON, Ken. Programming techniques: Regular expression search algorithm. Communications of the ACM, v. 11, n. 6, p. 419-422, 1968.
